# %% [markdown]
# #  Proof of technology

# %%
import glob
from subprocess import call

# %%
pdfs = [pdf for pdf in glob.glob('../data/**') if 'AER' in pdf]

# %%
filepath =  pdfs[0]
filepath
# Out:
# '../data/AER-2003-sample1.pdf'

# %%
fileobj = open(filepath,'rb')

# %% [markdown]
# ## Outline of the Paper

# %%
print(outline)
# Out:
# ('<outlines>\n<outline level="1" title="Are Idle Hands the Devil\xe2\x80\x99s Workshop? Incapacitation, Concentration, and Juvenile Crime">\n</outline>\n<outline level="2" title="I. Understanding and Identifying the School-Crime Relationship">\n</outline>\n<outline level="3" title="A. Conceptual Framework">\n</outline>\n<outline level="3" title="B. Identification Strategy">\n</outline>\n<outline level="3" title="C. Temporal Displacement">\n</outline>\n<outline level="2" title="II. Data">\n</outline>\n<outline level="3" title="A. Measures of Criminal Activity">\n</outline>\n<outline level="3" title="B. The Four &#34;W\xe2\x80\x99s\xe2\x80\x9d of Juvenile Crime">\n</outline>\n<outline level="3" title="C. Estimation Strategy">\n</outline>\n<outline level="2" title="III. Results">\n</outline>\n<outline level="3" title="A. Temporal Displacement">\n</outline>\n<outline level="3" title="B. Sensitivity Analyses">\n</outline>\n<outline level="3" title="C. The Heterogeneity of Schooling Effect
# ...

# %% [markdown]
# ## Full Text of the Paper

# %%
print(fulltext)
# Out:
# ("Are Idle Hands the Devil\xe2\x80\x99s Workshop?\n\nIncapacitation, Concentration, and Juvenile Crime\n\nBy BRIAN A. JACOB AND LARS LEFGREN*\n\nThis paper examines the short-term effect of school on juvenile crime. To do so, we\nbring together daily measures of criminal activity and detailed school calendar\ninformation from 29 jurisdictions across the country, and utilize the plausibly\nexogenous variation generated by teacher in-service days. We \xef\xac\x81nd that the level of\nproperty crime committed by juveniles decreases by 14 percent on days when school\nis in session, but the level of violent crime increases by 28 percent on such days. Our\n\xef\xac\x81ndings suggest\nthat both incapacitation and concentration in\xef\xac\x82uence juvenile\ncrime. (JEL I0, I2, H4)\n\nJuvenile crime touches millions of people in\nthe United States each year, imposing substan-\ntial costs on society. In 1997, law enforcement\nof\xef\xac\x81cials arrested 2.8 million people under the\nage of 18
# ...

# %%
title
# Out:
# 'Are Idle Hands the Devil\xe2\x80\x99s Workshop?\n\nIncapacitation, Concentration, and Juvenile Crime\n'

# %%
author
# Out:
# 'BRIAN A. JACOB AND LARS LEFGREN*'

# %% [markdown]
# ## Citations

# %%
citations_list
# Out:
# ['1.Daiji Kawaguchi. 2016. Fewer school days, more inequality. Journal of the Japanese and InternationalEconomies 39, 35-52. ',
#  "2.George F. N. Shoukry. 2016. CRIMINALS' RESPONSE TO CHANGING CRIME LUCRE.Economic Inquiry n/a-n/a. ",
#  '3.Ya Yu, C. Nicholas Mckinney, Steven B. Caudill, Franklin G. Mixon. 2016. Athletic contests andindividual robberies: an analysis based on hourly crime data. Applied Economics 48, 723-730. ',
#  '4.Daiji Kawaguchi. 2016. Fewer school days, more inequality. Economics of Education Review . ',
#  '5.Scott Cunningham, Benjamin Engelst\xc3\xa4tter, Michael R. Ward. 2016. Violent Video Games and ViolentCrime. Southern Economic Journal n/a-n/a. ',
#  '6.Philip J. Cook, Songman Kang. 2016. Birthdays, Schooling, and Crime: Regression-DiscontinuityAnalysis of School Performance, Delinquency, Dropout, and Crime Initiation. American EconomicJournal: Applied Economics 8:1, 33-57. ',
# ...

# %%
len(citations_list) # number of citations
# Out:
# 72

# %% [markdown]
# # Extract PDF TABLES
# ### While this is a little messy now, with some work it be just fine

# %%
for i, row in enumerate(tables[0]):
    print i, ':',  row
# Out:
# 0 : [u'1564', u'', u'THE', u'AMERI', u'CANE', u'CONO', u'MICR', u'EVIE', u'W', u'DEC', u'EMBER2003']
# 1 : [u'', u'TABLE', u'1\u2014THEDIST', u'RIBUTIO', u'NOF', u'TEACHE', u'RIN-SE', u'RVICE', u'DAYSBYCITY', u'', u'']
# 2 : [u'', u'', u'', u'Distr', u'ibutio', u'nacross', u'days', u'ofthe', u'', u'', u'']
# 3 : [u'', u'', u'Mean', u'', u'', u'week', u'', u'', u'Distri', u'butionacross', u'seasons']
# 4 : [u'', u'', u'numbero', u'f', u'', u'', u'', u'', u'', u'', u'']
# 5 : [u'', u'', u'in-service', u'', u'', u'', u'', u'', u'Fall', u'Winter', u'Spring']
# 6 : [u'City', u'Population', u'days', u'Mon.', u'Tue.', u'Wed.', u'Thur.', u'Fri.', u'(Sept.\u2013Nov.)', u'(Dec.\u2013Feb.)', u'(Mar.\u2013June)']
# 7 : [u'Allcities(total)', u'140,208', u'3.67', u'0.18', u'0.07', u'0.11', u'0.16', u'0.47', u'0.49', u'0.25', u'0.25']
# 8 : [u'Allcities(analysis)', u'140,208', u'2.12', u'0.10', u'0.03', u'0.04', u'0.23', u'0.61', u'0.62', u'0.09', u'0.29']
# ...

# %%
for i, row in enumerate(tables[1]):
    print i, ':',  row
# Out:
# 0 : [u'VOL.93NO.5JACOBANDLEFGREN:THEEFFECTOFSCHOOLONJUVENILECRIME1569']
# 1 : [u'T2\u2014TMNJO100,000RSNW']
# 2 : [u'ABLEHEEANUMBEROFUVENILEFFENDERSPERESIDENTSONCHOOLANDONSCHOOLEEKDAYS']
# 3 : [u'Juvenileoffendersper100,000residents']
# 4 : [u'SeriousoffensesMinoroffenses']
# 5 : [u'AllPropertyViolentOtherAll']
# 6 : [u'Independentvariablescrimescrimescrimescrimescrimes']
# 7 : [u'Schooldays5.7123.4741.4560.7822.169']
# 8 : [u'(0.550)(0.363)(0.162)(0.087)(0.352)']
# 9 : [u'Nonschooldays5.4213.7700.9820.6681.884']
# 10 : [u'(0.533)(0.388)(0.104)(0.076)(0.289)']
# 11 : [u'Teacherin-servicedays6.1874.3871.0070.7932.338']
# 12 : [u'(0.522)(0.400)(0.132)(0.099)(0.449)']
# 13 : [u'Idiosyncraticbreaks6.1054.2571.1050.7441.890']
# 14 : [u'(0.744)(0.562)(0.146)(0.132)(0.251)']
# 15 : [u'Commonbreaks4.8363.5530.7100.5731.422']
# 16 : [u'(0.453)(0.365)(0.078)(0.076)(0.238)']
# 17 : [u'Holidays4.1522.8960.7700.4861.344']
# 18 : [u'(0.449)(0.309)(0.093)(0.081)(0.195)']
# ...

# %%
for i, row in enumerate(tables[2]):
    print i, ':',  row
# Out:
# 0 : [u'1570THEAMERICANECONOMICREVIEWDECEMBER2003']
# 1 : [u'TABLE3\u2014THERELATIONSHIPBETWEENREPORTEDJUVENILEOFFENDERSANDTHESCHOOLTERM']
# 2 : [u'(Dependentvariable\u2afdnumberofreportedjuvenileoffenders']
# 3 : [u'forthefollowingoffenses)']
# 4 : [u'Minor']
# 5 : [u'Seriousoffensesoffenses']
# 6 : [u'AllPropertyViolentOtherAll']
# 7 : [u'crimescrimescrimescrimescrimesIndependentvariables']
# 8 : [u'\u2afa0.0070.133\u2afa0.323\u2afa0.106\u2afa0.153Teacherin-serviceday']
# 9 : [u'(0.16)(2.78)(4.40)(1.07)(2.57)']
# 10 : [u'0.0320.154\u2afa0.204\u2afa0.089\u2afa0.079Idiosyncraticbreak']
# 11 : [u'(1.02)(4.17)(3.94)(1.13)(1.77)']
# 12 : [u'\u2afa0.1120.021\u2afa0.478\u2afa0.353\u2afa0.271Commonbreak']
# 13 : [u'(4.31)(0.71)(10.00)(5.18)(6.90)']
# 14 : [u'\u2afa0.268\u2afa0.179\u2afa0.418\u2afa0.343\u2afa0.388Holiday']
# 15 : [u'(10.63)(6.05)(9.85)(5.47)(10.30)']
# 16 : [u'\u2afa0.0180.068\u2afa0.220\u2afa0.105\u2afa0.128Summervacation']
# 17 : [u'(0.89)(2.90)(6.52)(2.60)(4.33)']
# ...

# %%
for i, row in enumerate(tables[3]):
    print i, ':',  row
# Out:
# 0 : [u'VOL.93NO.5JACOBANDLEFGREN:THEEFFE', u'CTOFSCHOOLONJUVENILECRIME1571']
# 1 : [u'TABLE4\u2014THERELATIONSHIPBETWEENREPO', u'RTEDJUVENILEOFFENDERSANDTHESCHOOLTERM']
# 2 : [u'(Dependentvariable\u2afdnumbero', u'freportedjuvenilesoffendersforthefollowingoffenses)']
# 3 : [u'Se', u'Minorrious']
# 4 : [u'ViolentcrimesPr', u'opertycrimesOtherCurfew']
# 5 : [u'', u'or']
# 6 : [u'VehicleAggravatedSimpleIndependent', u'loiteringDisorderlyDrug']
# 7 : [u'theftSBurglaryvariablesassaultassault', u'violationhopliftingVandalismRobberyconductviolations']
# 8 : [u'0.234\u2afa0.047Teacherin-service\u2afa0.372\u2afa0.215', u'0.195\u2afa0.093\u2afa0.5140.2240.2430.177']
# 9 : [u'(1.80)(0.26)days(4.25)(1.29)', u'(0.92)(0.84)(2.86)(1.28)(3.74)(1.96)']
# 10 : [u'YesYesCity\u2d31month\u2d31YesYes', u'YesYesYesYesYesYes']
# 11 : [u'yearandday-', u'']
# 12 : [u'of-week\ufb01xed', u'']
# 13 : [u'effects', u'']
# 14 : [u'Observations31,86238,15735,53832,597', u'37,94136,90921,31636,42730,18718,399']
# ...

# %%
for i, row in enumerate(tables[4]):
    print i, ':',  row
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-73651b5d54c4> in <module>()
# ----> 1 for i, row in enumerate(tables[4]):
#       2     print i, ':',  row
#
# IndexError: list index out of range

# %%
len(tables)
# Out:
# 4

# %% [markdown]
# ### It looks like the current open source software that I am using missed on table, but that will just take some adjusting.
